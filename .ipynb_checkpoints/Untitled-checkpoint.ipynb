# %%
import pandas as pd
import os
from datetime import datetime, timedelta
from toad.plotter import plot_hist_prices

from toad.constants import myPath

# %%
start = datetime(2015, 1, 1)
end = datetime.today()

dates = pd.date_range(start, end)
instruments = pd.read_csv(os.path.join(myPath, 'available_instruments.csv'), sep='\t')
instruments
# Out:
#      Unnamed: 0        name      type displayName  pipLocation  \
# 0             0     GBP_USD  CURRENCY     GBP/USD           -4
# 1             1     USD_MXN  CURRENCY     USD/MXN           -4
# 2             2     XAG_USD     METAL      Silver           -4
# 3             3     EUR_ZAR  CURRENCY     EUR/ZAR           -4
# 4             4  NAS100_USD       CFD  US Nas 100            0
# ..          ...         ...       ...         ...          ...
# 119         119     XAG_NZD     METAL  Silver/NZD           -4
# 120         120     AUD_CAD  CURRENCY     AUD/CAD           -4
# 121         121     USD_CZK  CURRENCY     USD/CZK           -4
# 122         122     USD_CAD  CURRENCY     USD/CAD           -4
# 123         123     AUD_JPY  CURRENCY     AUD/JPY           -2
#
#      displayPrecision  tradeUnitsPrecision  minimumTradeSize  \
# 0                   5                    0                 1
# 1                   5                    0                 1
# ...

# %%
instrument = 'WTICO_USD'

# %%
silver = 
copper =

# %%
plot_hist_prices(instrument, mySerie)

# %%
bussiness_days_rng =pd.date_range(start, end, freq='BM')
bussiness_days_rng

# %%
date = bussiness_days_rng[-5]

tmp = pd.read_pickle(os.path.join(myPath, 'market_data', instrument, f"{date.strftime('%Y%m%d')}_{instrument}.pickle"))

plot_hist_prices(instrument, tmp)

# %%
mySerie['increment'] = (mySerie['closeAsk'] - mySerie['openAsk'])

# %%
mySerie['indicator'] = (mySerie['volume'] * mySerie['increment']).cumsum()

# %%
mySerie[['indicator', 'closeAsk']].plot()

plot_hist_prices(instrument, mySerie)
